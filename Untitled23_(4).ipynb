# %%
# Data and visualization
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# ML models
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from xgboost import XGBClassifier

# ANN
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping

# SMOTE for imbalance
from imblearn.over_sampling import SMOTE

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("/content/Student Depression Dataset.csv")  # 🔁 replace with your file name
print("Shape:", df.shape)
df.head()
# Out:
# Shape: (27901, 18)
#    id  Gender   Age           City Profession  Academic Pressure  \
# 0   2    Male  33.0  Visakhapatnam    Student                5.0
# 1   8  Female  24.0      Bangalore    Student                2.0
# 2  26    Male  31.0       Srinagar    Student                3.0
# 3  30  Female  28.0       Varanasi    Student                3.0
# 4  32  Female  25.0         Jaipur    Student                4.0
#
#    Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 0            0.0  8.97                 2.0               0.0
# 1            0.0  5.90                 5.0               0.0
# 2            0.0  7.03                 5.0               0.0
# 3            0.0  5.59                 2.0               0.0
# 4            0.0  8.13                 3.0               0.0
#
#       Sleep Duration Dietary Habits   Degree  \
# 0          5-6 hours        Healthy  B.Pharm
# 1          5-6 hours       Moderate      BSc
# 2  Less than 5 hours        Healthy       BA
# 3          7-8 hours       Moderate      BCA
# 4          5-6 hours       Moderate   M.Tech
#
#   Have you ever had suicidal thoughts ?  Work/Study Hours  Financial Stress  \
# 0                                   Yes               3.0               1.0
# 1                                    No               3.0               2.0
# 2                                    No               9.0               1.0
# 3                                   Yes               4.0               5.0
# 4                                   Yes               1.0               1.0
#
#   Family History of Mental Illness  Depression
# 0                               No           1
# 1                              Yes           0
# 2                              Yes           0
# 3                              Yes           1
# 4                               No           0

# %%
df.describe()
# Out:
#                   id           Age  Academic Pressure  Work Pressure  \
# count   27901.000000  27901.000000       27901.000000   27901.000000
# mean    70442.149421     25.822300           3.141214       0.000430
# std     40641.175216      4.905687           1.381465       0.043992
# min         2.000000     18.000000           0.000000       0.000000
# 25%     35039.000000     21.000000           2.000000       0.000000
# 50%     70684.000000     25.000000           3.000000       0.000000
# 75%    105818.000000     30.000000           4.000000       0.000000
# max    140699.000000     59.000000           5.000000       5.000000
#
#                CGPA  Study Satisfaction  Job Satisfaction  Work/Study Hours  \
# count  27901.000000        27901.000000      27901.000000      27901.000000
# mean       7.656104            2.943837          0.000681          7.156984
# std        1.470707            1.361148          0.044394          3.707642
# min        0.000000            0.000000          0.000000          0.000000
# 25%        6.290000            2.000000          0.000000          4.000000
# 50%        7.770000            3.000000          0.000000          8.000000
# 75%        8.920000            4.000000          0.000000         10.000000
# max       10.000000            5.000000          4.000000         12.000000
#
#        Financial Stress    Depression
# count      27898.000000  27901.000000
# mean           3.139867      0.585499
# std            1.437347      0.492645
# min            1.000000      0.000000
# 25%            2.000000      0.000000
# 50%            3.000000      1.000000
# 75%            4.000000      1.000000
# max            5.000000      1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27901 entries, 0 to 27900
# Data columns (total 18 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     27901 non-null  int64
#  1   Gender                                 27901 non-null  object
#  2   Age                                    27901 non-null  float64
#  3   City                                   27901 non-null  object
#  4   Profession                             27901 non-null  object
#  5   Academic Pressure                      27901 non-null  float64
#  6   Work Pressure                          27901 non-null  float64
#  7   CGPA                                   27901 non-null  float64
#  8   Study Satisfaction                     27901 non-null  float64
#  9   Job Satisfaction                       27901 non-null  float64
#  10  Sleep Duration                         27901 non-null  object
#  11  Dietary Habits                         27901 non-null  object
#  12  Degree                                 27901 non-null  object
#  13  Have you ever had suicidal thoughts ?  27901 non-null  object
#  14  Work/Study Hours                       27901 non-null  float64
#  15  Financial Stress                       27898 non-null  float64
#  16  Family History of Mental Illness       27901 non-null  object
#  17  Depression                             27901 non-null  int64
# dtypes: float64(8), int64(2), object(8)
# memory usage: 3.8+ MB

# %%
df.tail()
# Out:
#            id  Gender   Age       City Profession  Academic Pressure  \
# 27896  140685  Female  27.0      Surat    Student                5.0
# 27897  140686    Male  27.0   Ludhiana    Student                2.0
# 27898  140689    Male  31.0  Faridabad    Student                3.0
# 27899  140690  Female  18.0   Ludhiana    Student                5.0
# 27900  140699    Male  27.0      Patna    Student                4.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 27896            0.0  5.75                 5.0               0.0
# 27897            0.0  9.40                 3.0               0.0
# 27898            0.0  6.61                 4.0               0.0
# 27899            0.0  6.88                 2.0               0.0
# 27900            0.0  9.24                 1.0               0.0
#
#           Sleep Duration Dietary Habits    Degree  \
# 27896          5-6 hours      Unhealthy  Class 12
# 27897  Less than 5 hours        Healthy       MSc
# 27898          5-6 hours      Unhealthy        MD
# 27899  Less than 5 hours        Healthy  Class 12
# 27900  Less than 5 hours        Healthy       BCA
#
#       Have you ever had suicidal thoughts ?  Work/Study Hours  \
# 27896                                   Yes               7.0
# 27897                                    No               0.0
# 27898                                    No              12.0
# 27899                                   Yes              10.0
# 27900                                   Yes               2.0
#
#        Financial Stress Family History of Mental Illness  Depression
# 27896               1.0                              Yes           0
# 27897               3.0                              Yes           0
# 27898               2.0                               No           0
# 27899               5.0                               No           1
# 27900               3.0                              Yes           1

# %%
# --- Preprocessing: Convert 'Sleep Duration' to Numerical ---

# First, let's inspect the unique values in the column
print("Original unique values in 'Sleep Duration':")
print(df['Sleep Duration'].unique())

# Create a mapping dictionary to convert categories to numerical values
sleep_mapping = {
    'Less than 5 hours': 4.5,  # A value representing less than 5
    '5-6 hours': 5.5,          # The average of 5 and 6
    '7-8 hours': 7.5,          # The average of 7 and 8
    'More than 8 hours': 9.0   # A value representing more than 8
}

# Apply the mapping to the 'Sleep Duration' column
df['Sleep Duration'] = df['Sleep Duration'].map(sleep_mapping)

print("\n--- After Conversion ---")
print("Data type of 'Sleep Duration' column:", df['Sleep Duration'].dtype)
print("\nFirst 5 rows of the converted column:")
print(df[['Sleep Duration']].head())
# Out:
# Original unique values in 'Sleep Duration':
# ['5-6 hours' 'Less than 5 hours' '7-8 hours' 'More than 8 hours' 'Others']
#
# --- After Conversion ---
# Data type of 'Sleep Duration' column: float64
#
# First 5 rows of the converted column:
#    Sleep Duration
# 0             5.5
# 1             5.5
# 2             4.5
# 3             7.5
# 4             5.5

# %%
df.head()
# Out:
#    id  Gender   Age           City Profession  Academic Pressure  \
# 0   2    Male  33.0  Visakhapatnam    Student                5.0
# 1   8  Female  24.0      Bangalore    Student                2.0
# 2  26    Male  31.0       Srinagar    Student                3.0
# 3  30  Female  28.0       Varanasi    Student                3.0
# 4  32  Female  25.0         Jaipur    Student                4.0
#
#    Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  Sleep Duration  \
# 0            0.0  8.97                 2.0               0.0             5.5
# 1            0.0  5.90                 5.0               0.0             5.5
# 2            0.0  7.03                 5.0               0.0             4.5
# 3            0.0  5.59                 2.0               0.0             7.5
# 4            0.0  8.13                 3.0               0.0             5.5
#
#   Dietary Habits   Degree Have you ever had suicidal thoughts ?  \
# 0        Healthy  B.Pharm                                   Yes
# 1       Moderate      BSc                                    No
# 2        Healthy       BA                                    No
# 3       Moderate      BCA                                   Yes
# 4       Moderate   M.Tech                                   Yes
#
#    Work/Study Hours  Financial Stress Family History of Mental Illness  \
# 0               3.0               1.0                               No
# 1               3.0               2.0                              Yes
# 2               9.0               1.0                              Yes
# 3               4.0               5.0                              Yes
# 4               1.0               1.0                               No
#
#    Depression
# 0           1
# 1           0
# 2           0
# 3           1
# 4           0

# %%
print("✅ Null Values:\n", df.isnull().sum())
print("\n✅ Duplicate Rows:", df.duplicated().sum())

# Drop duplicates if any
df.drop_duplicates(inplace=True)
# Out:
# ✅ Null Values:
#  id                                        0
# Gender                                    0
# Age                                       0
# City                                      0
# Profession                                0
# Academic Pressure                         0
# Work Pressure                             0
# CGPA                                      0
# Study Satisfaction                        0
# Job Satisfaction                          0
# Sleep Duration                           18
# Dietary Habits                            0
# Degree                                    0
# Have you ever had suicidal thoughts ?     0
# Work/Study Hours                          0
# Financial Stress                          3
# Family History of Mental Illness          0
# Depression                                0
# dtype: int64
#
# ✅ Duplicate Rows: 0

# %%
plt.figure(figsize=(12, 6))
df.hist(bins=20, figsize=(15,10), color='skyblue', edgecolor='black')
plt.suptitle("Univariate Analysis (Histograms)", fontsize=14)
plt.show()

# For categorical columns
cat_cols = df.select_dtypes(include='object').columns
for col in cat_cols:
    plt.figure(figsize=(6,4))
    sns.countplot(x=df[col], palette='coolwarm')
    plt.title(f'Distribution of {col}')
    plt.show()

# %%
# Correlation heatmap
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap (Bivariate Relationship)")
plt.show()

# Example: Depression vs other features
target = 'Depression'
if target in df.columns:
    for col in df.select_dtypes(include=['int64','float64']).columns:
        if col != target:
            plt.figure(figsize=(6,4))
            sns.boxplot(x=target, y=col, data=df, palette='Set2')
            plt.title(f"{col} vs Depression")
            plt.show()

# %%
numeric_cols = df.select_dtypes(include=['int64', 'float64']).columns

for col in numeric_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    df = df[(df[col] >= lower) & (df[col] <= upper)]

print("✅ Shape after removing outliers:", df.shape)
# Out:
# ✅ Shape after removing outliers: (27857, 18)

# %%
plt.figure(figsize=(12,6))
sns.boxplot(data=df[numeric_cols])
plt.title("Boxplot After Outlier Removal (IQR)")
plt.show()

# %%
df['Depression'].value_counts()
# Out:
# Depression
# 1    16319
# 0    11538
# Name: count, dtype: int64

# %%
X = df.drop('Depression', axis=1)
y = df['Depression']

# %%
X = pd.get_dummies(X, drop_first=True)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
sns.countplot(x=y)
plt.title("Class Distribution Before SMOTE")
plt.show()

# %%
sm = SMOTE(random_state=42)
X_res, y_res = sm.fit_resample(X_scaled, y)

sns.countplot(x=y_res)
plt.title("Class Distribution After SMOTE")
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(X_res, y_res, test_size=0.2, random_state=42)

# %%
models = {
    'Logistic Regression': LogisticRegression(),
    'KNN': KNeighborsClassifier(),
    'Decision Tree': DecisionTreeClassifier(),
    'Random Forest': RandomForestClassifier(),
    'SVM': SVC(),
    'Naive Bayes': GaussianNB(),
    'XGBoost': XGBClassifier(use_label_encoder=False, eval_metric='logloss')
}

base_acc = {}
for name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    acc = accuracy_score(y_test, y_pred)
    base_acc[name] = acc
    print(f"{name} Accuracy: {acc:.4f}")
    print(f"{name} Classification Report:\n{classification_report(y_test, y_pred)}\n")
# Out:
# Logistic Regression Accuracy: 0.8476
# Logistic Regression Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.84      0.84      3215
#            1       0.85      0.85      0.85      3313
#
#     accuracy                           0.85      6528
#    macro avg       0.85      0.85      0.85      6528
# weighted avg       0.85      0.85      0.85      6528
#
#
# KNN Accuracy: 0.7687
# KNN Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.74      0.82      0.78      3215
#            1       0.80      0.72      0.76      3313
#
#     accuracy                           0.77      6528
#    macro avg       0.77      0.77      0.77      6528
# weighted avg       0.77      0.77      0.77      6528
#
#
# Decision Tree Accuracy: 0.8059
# Decision Tree Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.80      0.80      0.80      3215
#            1       0.81      0.81      0.81      3313
#
#     accuracy                           0.81      6528
#    macro avg       0.81      0.81      0.81      6528
# weighted avg       0.81      0.81      0.81      6528
#
#
# Random Forest Accuracy: 0.8655
# Random Forest Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.87      0.85      0.86      3215
#            1       0.86      0.88      0.87      3313
#
#     accuracy                           0.87      6528
#    macro avg       0.87      0.87      0.87      6528
# weighted avg       0.87      0.87      0.87      6528
#
#
# SVM Accuracy: 0.8496
# SVM Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.84      0.85      3215
#            1       0.85      0.85      0.85      3313
#
#     accuracy                           0.85      6528
#    macro avg       0.85      0.85      0.85      6528
# weighted avg       0.85      0.85      0.85      6528
#
#
# Naive Bayes Accuracy: 0.4930
# Naive Bayes Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.49      1.00      0.66      3215
#            1       0.80      0.00      0.00      3313
#
#     accuracy                           0.49      6528
#    macro avg       0.65      0.50      0.33      6528
# weighted avg       0.65      0.49      0.33      6528
#
#
# XGBoost Accuracy: 0.8614
# XGBoost Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.87      0.85      0.86      3215
#            1       0.86      0.87      0.86      3313
#
#     accuracy                           0.86      6528
#    macro avg       0.86      0.86      0.86      6528
# weighted avg       0.86      0.86      0.86      6528

# %%
# 🔧 Reduced Hyperparameter Grid (faster GridSearch)
param_grids = {
    "Logistic Regression": {
        'C': [0.1, 1],
        'solver': ['liblinear']  # works well for small to medium datasets
    },
    "Decision Tree": {
        'criterion': ['gini'],
        'max_depth': [5, 10, None],
        'min_samples_split': [2, 5]
    },
    "Random Forest": {
        'n_estimators': [100],
        'max_depth': [10, None],
        'min_samples_split': [2, 5]
    },
    "SVM": {
        'C': [1, 10],
        'kernel': ['linear', 'rbf'],  # 'poly' often slower, less needed
        'gamma': ['scale']
    },
    "KNN": {
        'n_neighbors': [3, 5, 7],
        'weights': ['uniform']
    },
    "XGBoost": {
        'n_estimators': [100],
        'learning_rate': [0.1],
        'max_depth': [3, 5],
        'colsample_bytree': [1.0]
    }
}

# 🔍 Grid Search Loop (same)
tuned_results = []
for name, params in param_grids.items():
    print(f"\n🔍 Tuning {name}...")
    grid = GridSearchCV(models[name], params, cv=3, scoring='accuracy', n_jobs=-1)
    grid.fit(X_train, y_train)
    best_model = grid.best_estimator_
    y_pred = best_model.predict(X_test)
    tuned_results.append([name, accuracy_score(y_test, y_pred)])

# 📊 Print tuned accuracies
print("\n📊 Hyperparameter Tuning Accuracies:")
for name, acc in tuned_results:
    print(f"{name}: {acc:.4f}")
# Out:
# 🔍 Tuning Logistic Regression...
#
# 🔍 Tuning Decision Tree...
#
# 🔍 Tuning Random Forest...
#
# 🔍 Tuning SVM...
#
# 🔍 Tuning KNN...
#
# 🔍 Tuning XGBoost...
#
# 📊 Hyperparameter Tuning Accuracies:
# Logistic Regression: 0.8476
# Decision Tree: 0.8390
# Random Forest: 0.8689
# SVM: 0.8496
# KNN: 0.7727
# XGBoost: 0.8684

# %%
ann = Sequential([
    Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    BatchNormalization(),
    Dropout(0.3),
    Dense(32, activation='relu'),
    BatchNormalization(),
    Dropout(0.3),
    Dense(1, activation='sigmoid')
])

ann.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

history = ann.fit(X_train, y_train, validation_split=0.2, epochs=50, batch_size=32, callbacks=[early_stop], verbose=1)
# Out:
# Epoch 1/50
# 653/653 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.6706 - loss: 0.6522 - val_accuracy: 0.8441 - val_loss: 0.3607
# Epoch 2/50
# 653/653 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8269 - loss: 0.3948 - val_accuracy: 0.8481 - val_loss: 0.3524
# Epoch 3/50
# 653/653 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8329 - loss: 0.3813 - val_accuracy: 0.8514 - val_loss: 0.3528
# Epoch 4/50
# 653/653 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8460 - loss: 0.3591 - val_accuracy: 0.8522 - val_loss: 0.3488
# Epoch 5/50
# 653/653 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8451 - loss: 0.3614 - val_accuracy: 0.8508 - val_loss: 0.3503
# Epoch 6/50
# 653/653 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8474 - loss: 0.3586 - val_accuracy: 0.8501 - val_loss: 0.3463
# Epoch 7/50
# 653/653 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8488 - loss: 0.3519 - val_accuracy: 0.8527 - val_loss: 0.3464
# Epoch 8/50
# 653/653 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8519 - loss: 0.3504 - val_accuracy: 0.8556 - val_loss: 0.3464
# Epoch 9/50
# 653/653 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8532 - loss: 0.3497 - val_accuracy: 0.8518 - val_loss: 0.3465
# Epoch 10/50
# 653/653 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8520 - loss: 0.3455 - val_accuracy: 0.8499 - val_loss: 0.3474
# Epoch 11/50
# 653/653 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8538 - loss: 0.3453 - val_accuracy: 0.8506 - val_loss: 0.3510

# %%
ann_acc = ann.evaluate(X_test, y_test, verbose=0)[1]
print("ANN Accuracy:", ann_acc)
# Out:
# ANN Accuracy: 0.8452818393707275

# %%
final_results = {**base_acc, **dict(tuned_results), 'ANN': ann_acc}
df_results = pd.DataFrame(list(final_results.items()), columns=['Model', 'Accuracy']).sort_values(by='Accuracy', ascending=False)

plt.figure(figsize=(10,6))
sns.barplot(x='Accuracy', y='Model', data=df_results, palette='viridis')
plt.title("Final Model Accuracy Comparison")
plt.show()

df_results
# Out:
#                  Model  Accuracy
# 3        Random Forest  0.868873
# 6              XGBoost  0.868413
# 4                  SVM  0.849571
# 0  Logistic Regression  0.847580
# 7                  ANN  0.845282
# 2        Decision Tree  0.839001
# 1                  KNN  0.772672
# 5          Naive Bayes  0.492953

# %%
best_model = df_results.iloc[0]
print(f"🏆 Best Model: {best_model['Model']}  |  Accuracy: {best_model['Accuracy']:.4f}")
# Out:
# 🏆 Best Model: Random Forest  |  Accuracy: 0.8689
